# %%
import cv2
import mediapipe as mp
import numpy as np
import os

mp_pose = mp.solutions.pose
pose = mp_pose.Pose()
mp_drawing = mp.solutions.drawing_utils

video_path = r"C:\Users\dogat\Desktop\DL_Vidoes" # Update this path
keypoints_data = []

for file in os.listdir(video_path):
    if file.endswith(".mp4"):
        cap = cv2.VideoCapture(os.path.join(video_path, file))

        while cap.isOpened():
            ret, frame = cap.read()
            if not ret:
                break

            frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            results = pose.process(frame_rgb)

            if results.pose_landmarks:
                keypoints = [ 
                    (lm.x, lm.y, lm.z) for lm in results.pose_landmarks.landmark
                ]
                keypoints_data.append(keypoints)

        cap.release()

keypoints_data = np.array(keypoints_data)
np.save("pose_data.npy", keypoints_data)  # Save extracted features

# %%
def label_squat(landmarks):
    hip_y = landmarks[mp_pose.PoseLandmark.LEFT_HIP.value][1]  # Y-coordinate of the left hip
    return "DOWN" if hip_y > 0.6 else "UP"  # Adjust threshold based on video

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

X_train = np.load("pose_data.npy")  # Load extracted features
y_train = np.array([label_squat(frame) for frame in X_train])  # Convert labels to array

# Convert labels to numeric values (0 = DOWN, 1 = UP)
y_train = np.array([0 if label == "DOWN" else 1 for label in y_train])

# Build LSTM model
model = Sequential([
    LSTM(64, return_sequences=True, input_shape=(33, 3)),  # 33 keypoints with (x, y, z)
    LSTM(32),
    Dense(16, activation="relu"),
    Dense(1, activation="sigmoid")  # Binary classification (UP or DOWN)
])

model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])
model.fit(X_train, y_train, epochs=10, batch_size=32)

# Save the model
model.save("squat_classifier2.h5")
# Out:
# Epoch 1/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.6876 - loss: 0.6353
# Epoch 2/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.8177 - loss: 0.4292
# Epoch 3/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.8616 - loss: 0.3234
# Epoch 4/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.8581 - loss: 0.3255
# Epoch 5/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8978 - loss: 0.2576
# Epoch 6/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8854 - loss: 0.2692
# Epoch 7/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9051 - loss: 0.2300
# Epoch 8/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - accuracy: 0.9164 - loss: 0.2140
# Epoch 9/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.9245 - loss: 0.1893
# Epoch 10/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9126 - loss: 0.2079
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import cv2
import mediapipe as mp
import os
import numpy as np
import tensorflow as tf

class poseDetector():
    def __init__(self, mode=False, upBody=False, smooth=True, detectionCon=True, trackCon=0.5):
        self.mpDraw = mp.solutions.drawing_utils
        self.mpPose = mp.solutions.pose
        self.pose = self.mpPose.Pose(mode, upBody, smooth, detectionCon, trackCon)

    def findPose(self, img, draw=True):
        imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        self.results = self.pose.process(imgRGB)  # Use the pose object to process the frame
        if self.results.pose_landmarks and draw:
            self.mpDraw.draw_landmarks(img, self.results.pose_landmarks, self.mpPose.POSE_CONNECTIONS)
        return img

    def findPosition(self, img):
        lmList = []
        if self.results.pose_landmarks:
            for id, lm in enumerate(self.results.pose_landmarks.landmark):
                h, w, _ = img.shape
                cx, cy = int(lm.x * w), int(lm.y * h)
                lmList.append([id, cx, cy, lm.x, lm.y, lm.z])
        return lmList

def classify_frame(frame, model, pose, squat_threshold=0.5):
    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    results = pose.pose.process(frame_rgb)  # Fix here: Access `pose.process`

    if results.pose_landmarks:
        # Extract all 33 keypoints (x, y, z)
        keypoints = np.array([[lm.x, lm.y, lm.z] for lm in results.pose_landmarks.landmark])
        keypoints = np.expand_dims(keypoints, axis=0)  # Reshape to (1, 33, 3)

        # Make prediction
        prediction = model.predict(keypoints)[0][0]
        print(f"Model prediction: {prediction}, Threshold: {squat_threshold}")

        label = "UP" if prediction > squat_threshold else "DOWN"
    else:
        label = "UNKNOWN"

    return label, results.pose_landmarks

# Load model
model = tf.keras.models.load_model("squat_classifier2.h5")

# Open the video
video_path = r"C:\Users\dogat\Desktop\DL_Vidoes\fortSquat1.mov"  # Change file name if needed
cap = cv2.VideoCapture(video_path)

# Initialize pose detector
pose = poseDetector()

# Initialize frame predictions for smoothing (e.g., last 5 frames)
frame_predictions = []

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Get classification label and pose landmarks
    label, landmarks = classify_frame(frame, model, pose)

    # Append the current prediction (1 for "UP", 0 for "DOWN") to the list
    frame_predictions.append(1 if label == "UP" else 0)

    # Keep only the last 5 predictions (e.g., smoothing over 5 frames)
    if len(frame_predictions) > 5:
        frame_predictions.pop(0)

    # Apply majority voting or moving average for smoothing
    if np.mean(frame_predictions) > 0.5:
        final_label = "UP"
    else:
        final_label = "DOWN"

    # If landmarks exist, draw them
    if landmarks:
        mp.solutions.drawing_utils.draw_landmarks(frame, landmarks, mp.solutions.pose.POSE_CONNECTIONS)

    # Overlay final label on frame
    cv2.putText(frame, final_label, (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

    # Display the frame with keypoints and label
    cv2.imshow("Pose Estimation with Label", frame)

    # Exit loop if 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step
# Model prediction: 0.9965253472328186, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Model prediction: 0.9927159547805786, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Model prediction: 0.9894998073577881, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Model prediction: 0.9848856925964355, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Model prediction: 0.9908884763717651, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Model prediction: 0.9899758100509644, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Model prediction: 0.9895860552787781, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Model prediction: 0.9908852577209473, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Model prediction: 0.9907795190811157, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Model prediction: 0.9908376932144165, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Model prediction: 0.9912947416305542, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Model prediction: 0.9912204742431641, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Model prediction: 0.9927502870559692, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Model prediction: 0.9930412173271179, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Model prediction: 0.9935200810432434, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Model prediction: 0.9935283064842224, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Model prediction: 0.9895367622375488, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Model prediction: 0.9886226654052734, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Model prediction: 0.9836440086364746, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Model prediction: 0.9865843057632446, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Model prediction: 0.9891940951347351, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Model prediction: 0.9860880970954895, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Model prediction: 0.9845825433731079, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Model prediction: 0.9813951849937439, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Model prediction: 0.8731215596199036, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Model prediction: 0.6341609954833984, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Model prediction: 0.9275369048118591, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Model prediction: 0.9408013224601746, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Model prediction: 0.9686709046363831, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Model prediction: 0.9576642513275146, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Model prediction: 0.8553285598754883, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Model prediction: 0.9201473593711853, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Model prediction: 0.780340313911438, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Model prediction: 0.8939779996871948, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Model prediction: 0.8991559147834778, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Model prediction: 0.8415050506591797, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Model prediction: 0.8941291570663452, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Model prediction: 0.8464870452880859, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Model prediction: 0.894598662853241, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Model prediction: 0.8673096299171448, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Model prediction: 0.8340696096420288, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Model prediction: 0.9178168773651123, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Model prediction: 0.8773706555366516, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Model prediction: 0.8590792417526245, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Model prediction: 0.886463463306427, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Model prediction: 0.8973196744918823, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Model prediction: 0.7081013917922974, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Model prediction: 0.6129703521728516, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Model prediction: 0.5505021810531616, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Model prediction: 0.533400297164917, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Model prediction: 0.5128533840179443, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Model prediction: 0.5134023427963257, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Model prediction: 0.4541841149330139, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Model prediction: 0.3478928506374359, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Model prediction: 0.2806389033794403, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Model prediction: 0.45421719551086426, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Model prediction: 0.3640376925468445, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Model prediction: 0.2188575565814972, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Model prediction: 0.13079030811786652, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Model prediction: 0.10224498808383942, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Model prediction: 0.0993770882487297, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Model prediction: 0.1068558543920517, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Model prediction: 0.07179038971662521, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Model prediction: 0.07771505415439606, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Model prediction: 0.048993196338415146, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Model prediction: 0.07589980959892273, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Model prediction: 0.07013678550720215, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Model prediction: 0.14365330338478088, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Model prediction: 0.08663070946931839, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Model prediction: 0.08366533368825912, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Model prediction: 0.03847995400428772, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Model prediction: 0.05819813907146454, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Model prediction: 0.09382104128599167, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Model prediction: 0.07411295175552368, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Model prediction: 0.05852437764406204, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Model prediction: 0.07214859873056412, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Model prediction: 0.045563653111457825, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Model prediction: 0.04725911468267441, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Model prediction: 0.04684474691748619, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Model prediction: 0.03730838745832443, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Model prediction: 0.09296602755784988, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Model prediction: 0.07485821098089218, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Model prediction: 0.12275692075490952, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Model prediction: 0.11672073602676392, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Model prediction: 0.11662837862968445, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Model prediction: 0.11879454553127289, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Model prediction: 0.14887575805187225, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Model prediction: 0.19300752878189087, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Model prediction: 0.18260596692562103, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Model prediction: 0.24890786409378052, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Model prediction: 0.24778011441230774, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Model prediction: 0.224736750125885, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Model prediction: 0.2215844839811325, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Model prediction: 0.2458466738462448, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Model prediction: 0.31579461693763733, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Model prediction: 0.3045350909233093, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Model prediction: 0.2836233973503113, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Model prediction: 0.255094975233078, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Model prediction: 0.33341512084007263, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Model prediction: 0.40946757793426514, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Model prediction: 0.5202339887619019, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# Model prediction: 0.5468116998672485, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Model prediction: 0.6033246517181396, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Model prediction: 0.6417778134346008, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Model prediction: 0.5455181002616882, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Model prediction: 0.5574591159820557, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# Model prediction: 0.9217420220375061, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Model prediction: 0.768984854221344, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Model prediction: 0.6587562561035156, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Model prediction: 0.6699023842811584, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Model prediction: 0.9610192775726318, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Model prediction: 0.8033791184425354, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Model prediction: 0.6901620626449585, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# Model prediction: 0.7764514684677124, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Model prediction: 0.7831218242645264, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Model prediction: 0.7452183365821838, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Model prediction: 0.8554772734642029, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Model prediction: 0.7804001569747925, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Model prediction: 0.8235647082328796, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Model prediction: 0.9310591220855713, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Model prediction: 0.9446474313735962, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Model prediction: 0.9333564639091492, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Model prediction: 0.8935211896896362, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Model prediction: 0.8854317665100098, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Model prediction: 0.8895914554595947, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Model prediction: 0.9366761445999146, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Model prediction: 0.9128196239471436, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Model prediction: 0.8700984716415405, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Model prediction: 0.751702070236206, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Model prediction: 0.575434684753418, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Model prediction: 0.8111097812652588, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Model prediction: 0.7872135043144226, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Model prediction: 0.865910530090332, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Model prediction: 0.8940590023994446, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Model prediction: 0.9695343971252441, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Model prediction: 0.9715709090232849, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Model prediction: 0.936958909034729, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Model prediction: 0.964258074760437, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Model prediction: 0.9721990823745728, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Model prediction: 0.9732146859169006, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Model prediction: 0.9564551115036011, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Model prediction: 0.9757899641990662, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Model prediction: 0.9804350733757019, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Model prediction: 0.9821242094039917, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Model prediction: 0.9863703846931458, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Model prediction: 0.9892733693122864, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Model prediction: 0.9935358762741089, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Model prediction: 0.9937556385993958, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Model prediction: 0.9946793913841248, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# Model prediction: 0.9944452047348022, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Model prediction: 0.9940434694290161, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Model prediction: 0.9931296110153198, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Model prediction: 0.9941599369049072, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Model prediction: 0.9929419159889221, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Model prediction: 0.9928248524665833, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Model prediction: 0.9924636483192444, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Model prediction: 0.9930632710456848, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Model prediction: 0.993516206741333, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Model prediction: 0.9928088784217834, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Model prediction: 0.993133008480072, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Model prediction: 0.9932060837745667, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Model prediction: 0.9931489825248718, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Model prediction: 0.9926153421401978, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Model prediction: 0.9924449920654297, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Model prediction: 0.9912134408950806, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Model prediction: 0.990736722946167, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Model prediction: 0.9892919659614563, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Model prediction: 0.9898970723152161, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Model prediction: 0.9899333119392395, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Model prediction: 0.989853024482727, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Model prediction: 0.989274263381958, Threshold: 0.5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Model prediction: 0.9900016188621521, Threshold: 0.5
